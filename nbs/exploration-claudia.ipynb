# %%
import matplotlib.pyplot as plt
from hashcode.utils import *
import hashcode.greedyC as greedy

# %% [markdown]
# # example

# %%
example = load('../dataset/a_example.txt')

# %%
freqs = [len(photo[1]) for photo in example]
plt.hist(freqs)

# %% [markdown]
# ### Small

# %%
b_small = load('../dataset/b_lovely_landscapes_small.txt')

# %%
# %load_ext autoreload
# %autoreload
solution = greedy.solve(b_small)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-6-ff14c46993fe> in <module>()
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '')
# ----> 3 solution = greedy.solve(b_small)
#
# ~/hashcode2019/hashcode/greedy.py in solve(input_photos)
#      18         for tag in photos[1]:
#      19             tags.setdefault(tag, set())
# ---> 20             tags[tag].add(photo)
#      21     photos = deque(x for x in input_photos)
#      22     solution = [photos.popleft()]
#
# UnboundLocalError: local variable 'photo' referenced before assignment

# %% [markdown]
# # B

# %%
B = load('../dataset/b_lovely_landscapes.txt')

# %%
freqs = [len(photo[1]) for photo in B]
plt.hist(freqs)

# %% [markdown]
# # C

# %%
C
# Out:
# [('V', 0, {'t17', 't1l', 't8b1', 'tg6', 'tjb1', 'tmz1', 'tw52'}),
#  ('H', 1, {'t6c', 't81', 'tc51', 'tgr', 'trn', 'twt1', 'tzb1'}),
#  ('V', 2, {'t001', 't201', 't4q', 't652', 't81', 'tb6', 'td7', 'tg11'}),
#  ('H',
#   3,
#   {'t0c',
#    't21',
#    't351',
#    't8b1',
#    'tg02',
#    'tl3',
#    'tms',
#    'tqp1',
#    'tqz1',
#    'twd1'}),
#  ('H',
#   4,
#   {'t2m1',
#    't4t1',
#    't6r1',
#    't892',
#    't9q1',
#    'tld1',
#    'tpb',
#    'trn',
#    'tsj1',
#    'tt',
#    'tv81',
#    'tz41'}),
#  ('H',
#   5,
#   {'t071',
#    't332',
#    't3b1',
#    't51',
#    't771',
#    't7d1',
#    't822',
#    't882',
#    'tbn1',
#    'tfg1',
#    'tn3',
#    'ttc1'}),
#  ('V',
#   6,
#   {'t14',
#    't291',
#    't502',
#    't9c1',
#    't9s',
#    'tj62',
#    'tlb',
#    'tpz1',
#    'tr51',
#    'trx'}),
#  ('H', 7, {'t2m1', 't2x1', 't5p1', 'tdm1', 'tjp', 'tk6', 'ttc', 'twg1'}),
#  ('V',
#   8,
#   {'t1',
#    't3t',
#    't561',
#    't76',
#    't911',
# ...

# %%
a = [('V', 0, {'t17', 't1l', 't8b1', 'tg6', 'tjb1', 'tmz1', 'tw52'}),
 ('H', 1, {'t6c', 't81', 'tc51', 'tgr', 'trn', 'twt1', 'tzb1'}),
 ('V', 2, {'t001', 't201', 't4q', 't652', 't81', 'tb6', 'td7', 'tg11'}),
 ('H',
  3,
  {'t0c',
   't21',
   't351',
   't8b1',
   'tg02',
   'tl3',
   'tms',
   'tqp1',
   'tqz1',
   'twd1'})]

# %%
temp[0][0]
# Out:
# 'V'

# %%
def convertVToH(input_photos):
    for i in range()

# %%
def convertVToH(input_photos):
    vertical = False
    res = []
    for photo in input_photos:
        print(photo[0])
        if photo[0] == 'V' and vertical == False:
            temp = list(photo)
            print(temp)
            vertical = True
        elif photo[0] == 'V' and vertical == True:
            temp[1] = [temp[1]] + [photo[1]]
            temp[2] = set(temp[2] & photo[2])
            vertical = False
            res.append(temp)
            print(res)
        else:
            res.append(photo)
            print(res)

# %%
convertVToH(a)
# Out:
# V
# ['V', 0, {'tw52', 't1l', 't17', 't8b1', 'tjb1', 'tmz1', 'tg6'}]
# H
# [('H', 1, {'tzb1', 't6c', 'tc51', 't81', 'twt1', 'trn', 'tgr'})]
# V
# [('H', 1, {'tzb1', 't6c', 'tc51', 't81', 'twt1', 'trn', 'tgr'}), ['V', [0, 2], set()]]
# H
# [('H', 1, {'tzb1', 't6c', 'tc51', 't81', 'twt1', 'trn', 'tgr'}), ['V', [0, 2], set()], ('H', 3, {'tl3', 'tg02', 'twd1', 't351', 't8b1', 'tqz1', 'tms', 't0c', 'tqp1', 't21'})]

# %%
C = load('../dataset/c_memorable_moments.txt')
C
# Out:
# [('V', 0, {'t17', 't1l', 't8b1', 'tg6', 'tjb1', 'tmz1', 'tw52'}),
#  ('H', 1, {'t6c', 't81', 'tc51', 'tgr', 'trn', 'twt1', 'tzb1'}),
#  ('V', 2, {'t001', 't201', 't4q', 't652', 't81', 'tb6', 'td7', 'tg11'}),
#  ('H',
#   3,
#   {'t0c',
#    't21',
#    't351',
#    't8b1',
#    'tg02',
#    'tl3',
#    'tms',
#    'tqp1',
#    'tqz1',
#    'twd1'}),
#  ('H',
#   4,
#   {'t2m1',
#    't4t1',
#    't6r1',
#    't892',
#    't9q1',
#    'tld1',
#    'tpb',
#    'trn',
#    'tsj1',
#    'tt',
#    'tv81',
#    'tz41'}),
#  ('H',
#   5,
#   {'t071',
#    't332',
#    't3b1',
#    't51',
#    't771',
#    't7d1',
#    't822',
#    't882',
#    'tbn1',
#    'tfg1',
#    'tn3',
#    'ttc1'}),
#  ('V',
#   6,
#   {'t14',
#    't291',
#    't502',
#    't9c1',
#    't9s',
#    'tj62',
#    'tlb',
#    'tpz1',
#    'tr51',
#    'trx'}),
#  ('H', 7, {'t2m1', 't2x1', 't5p1', 'tdm1', 'tjp', 'tk6', 'ttc', 'twg1'}),
#  ('V',
#   8,
#   {'t1',
#    't3t',
#    't561',
#    't76',
#    't911',
# ...

# %%
freqs = [len(photo[1]) for photo in C]
plt.hist(freqs)

# %%
# %load_ext autoreload
# %autoreload
solution = greedy.solve(C)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...

# %% [markdown]
# # D

# %%
D = load('../dataset/c_memorable_moments.txt')
D

# %%
freqs = [len(photo[1]) for photo in D]
plt.hist(freqs)

# %% [markdown]
# # E

# %%
E = load('../dataset/e_shiny_selfies.txt')
E

# %%
freqs = [len(photo[1]) for photo in E]
plt.hist(freqs)
